# %% [markdown]
# # Proyek Analisis Data: [Air quality dataset]
# - **Nama:** [Fakhri Muhammad Azzam]
# - **Email:** [m312d4ky1522@bangkit.academy]
# - **ID Dicoding:** [fakhriazzam]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - bagaimana trend kualitas udara di stasiun cina?
# - apa pengeruh hujan terhadap kualitas udara di stasiun cina?

# %% [markdown]
# ## Mengistall Requirement.txt

# %%
pip install -r requirements.txt
# Out:
# Processing e:\home\conda\feedstock_root\build_artifacts\exceptiongroup_1704921103267\work (from -r requirements.txt (line 16))Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'E:\\home\\conda\\feedstock_root\\build_artifacts\\exceptiongroup_1704921103267\\work'

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
Aotizhongxin_df =pd.read_csv("Dataset\\PRSA_Data_Aotizhongxin_20130301-20170228.csv")
Aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
Changping_df =pd.read_csv("Dataset\\PRSA_Data_Changping_20130301-20170228.csv")
Changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
Dingling_df =pd.read_csv("Dataset\\PRSA_Data_Dingling_20130301-20170228.csv")
Dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
Guangyuan_df = pd.read_csv("Dataset\\PRSA_Data_Dongsi_20130301-20170228.csv")
Guangyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
Gucheng_df = pd.read_csv("Dataset\\PRSA_Data_Guanyuan_20130301-20170228.csv")
Gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
Huairou_df = pd.read_csv("Dataset\\PRSA_Data_Gucheng_20130301-20170228.csv")
Huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
Nongzhang_df = pd.read_csv ("Dataset\\PRSA_Data_Huairou_20130301-20170228.csv")
Nongzhang_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
Shunyi_df = pd.read_csv ("Dataset\\PRSA_Data_Nongzhanguan_20130301-20170228.csv")
Shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
Tiantan_df = pd.read_csv ("Dataset\\PRSA_Data_Shunyi_20130301-20170228.csv")
Tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
Wanliu_df = pd.read_csv ("Dataset\\PRSA_Data_Tiantan_20130301-20170228.csv")
Wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
Wanshouxigong_df = pd.read_csv ("Dataset\\PRSA_Data_Wanliu_20130301-20170228.csv")
Wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
all_df = pd.concat([Aotizhongxin_df, Changping_df, Dingling_df, Guangyuan_df, Gucheng_df, Huairou_df, Nongzhang_df, Shunyi_df, Tiantan_df, Wanliu_df, Wanshouxigong_df], ignore_index=True)
all_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Dingling_df.info()

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385704 entries, 0 to 385703
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       385704 non-null  int64
#  1   year     385704 non-null  int64
#  2   month    385704 non-null  int64
#  3   day      385704 non-null  int64
#  4   hour     385704 non-null  int64
#  5   PM2.5    377661 non-null  float64
#  6   PM10     379739 non-null  float64
#  7   SO2      377352 non-null  float64
#  8   NO2      374342 non-null  float64
#  9   CO       366300 non-null  float64
#  10  O3       373505 non-null  float64
#  11  TEMP     385325 non-null  float64
#  12  PRES     385330 non-null  float64
#  13  DEWP     385320 non-null  float64
#  14  RAIN     385333 non-null  float64
#  15  wd       383961 non-null  object
#  16  WSPM     385399 non-null  float64
#  17  station  385704 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 53.0+ MB

# %%
all_df.isna().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8043
# PM10        5965
# SO2         8352
# NO2        11362
# CO         19404
# O3         12199
# TEMP         379
# PRES         374
# DEWP         384
# RAIN         371
# wd          1743
# WSPM         305
# station        0
# dtype: int64

# %%
print("Jumlah duplikasi: ", all_df.duplicated().sum())
all_df.describe()
# Out:
# Jumlah duplikasi:  0
#                   No           year          month            day  \
# count  385704.000000  385704.000000  385704.000000  385704.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.118037       1.177198       3.448708       8.800103
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  385704.000000  377661.000000  379739.000000  377352.000000
# mean       11.500000      79.317422     103.908644      15.710722
# std         6.922196      80.320205      91.192425      21.425689
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %% [markdown]
# ### Cleaning Data

# %%
all_df = all_df.interpolate(method='linear')
# Out:
# C:\Users\fakhr\AppData\Local\Temp\ipykernel_14124\3067939102.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   all_df = all_df.interpolate(method='linear')

# %%
all_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2           0
# CO            0
# O3            0
# TEMP          0
# PRES          0
# DEWP          0
# RAIN          0
# wd         1743
# WSPM          0
# station       0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Explore `all_df`

# %% [markdown]
# Menambahkan dataframe tanggal

# %%
all_df['date'] = pd.to_datetime(all_df[['year', 'month', 'day']])
all_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station       date
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin 2013-03-01
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin 2013-03-01
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin 2013-03-01
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin 2013-03-01
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin 2013-03-01

# %%
all_df.describe(include="all")
# Out:
#                    No           year          month            day  \
# count   385704.000000  385704.000000  385704.000000  385704.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17532.500000    2014.662560       6.522930      15.729637
# min          1.000000    2013.000000       1.000000       1.000000
# 25%       8766.750000    2014.000000       4.000000       8.000000
# 50%      17532.500000    2015.000000       7.000000      16.000000
# 75%      26298.250000    2016.000000      10.000000      23.000000
# max      35064.000000    2017.000000      12.000000      31.000000
# std      10122.118037       1.177198       3.448708       8.800103
#
#                  hour          PM2.5           PM10            SO2  \
# count   385704.000000  385704.000000  385704.000000  385704.000000
# ...

# %% [markdown]
# Mencari nilai tertinggi dari partikel udara

# %%
daily_df = all_df.groupby(by=["station", "year","month","day"]).agg({
    "PM2.5": "max",
    "PM10": "max",
    "SO2": "max",
    "NO2": "max",
    "CO": "max",
    "O3": "max"
})
daily_df.head()
# Out:
#                              PM2.5   PM10    SO2    NO2      CO    O3
# station      year month day
# Aotizhongxin 2013 3     1     24.0   24.0   26.0   57.0   700.0  77.0
#                         2     93.0  120.0   87.0  110.0  1700.0  52.0
#                         3    117.0  181.0  135.0  135.0  2799.0  77.0
#                         4     58.0   94.0   51.0   86.0  1300.0  84.0
#                         5    226.0  269.0  147.0  204.0  4400.0  84.0

# %%
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# Membuat Data Frame kondisi udara

# %%
air_df= daily_df

def determine_air_condition(row):
    if row['PM2.5'] <= 50 and row['PM10'] <= 50 and row['SO2'] <= 20 and row['NO2'] <= 40 and row['CO'] <= 1000 and row['O3'] <= 80:
        return "Baik"
    elif row['PM2.5'] <= 100 and row['PM10'] <= 50 and row['SO2'] <= 40 and row['NO2'] <= 100 and row['CO'] <= 2000 and row['O3'] <= 160:
        return "Sedang"
    elif row['PM2.5'] <= 250 and row['PM10'] <= 100 and row['SO2'] <= 200 and row['NO2'] <= 200 and row['CO'] <= 10000 and row['O3'] <= 200:
        return "Tidak Sehat"
    elif row['PM2.5'] <= 350 and row['PM10'] <= 250 and row['SO2'] <= 300 and row['NO2'] <= 400 and row['CO'] <= 17000 and row['O3'] <= 250:
        return "Sangat Tidak Sehat"
    else:
        return "Berbahaya"

air_df['Air_condition'] = air_df.apply(determine_air_condition, axis=1)



air_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 15
#      12     else:
#      13         return "Berbahaya"
# ---> 15 air_df['Air_condition'] = air_df.apply(determine_air_condition, axis=1)
#      19 air_df.head()
#
# File c:\Users\fakhr\anaconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py:10361, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10347 from pandas.core.apply import frame_apply
#   10349 op = frame_apply(
#   10350     self,
#   10351     func=func,
#    (...)
#   10359     kwargs=kwargs,
#   10360 )
# > 10361 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\fakhr\anaconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
# ...

# %% [markdown]
# membuat plot untuk tiap stasiun

# %%
sns.catplot(x="year", hue="Air_condition", kind="count", data=air_df, col="station")
plt.show()

# %% [markdown]
# Membuat grafik trend untuk seluruh stasiun

# %%
# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=air_df, x='month', y='Air_condition', hue='station', marker='o')
plt.title('Tren Kualitas Udara per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Air Condition')
plt.legend(title='Stasiun')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
rain_df = all_df

rain_df['RAIN'] = rain_df['RAIN'].apply(lambda x: 1 if x > 0 else 0)
kolom_udara = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']
rain = rain_df[rain_df['RAIN'] == 1][kolom_udara]
not_rain = rain_df[rain_df['RAIN'] == 0][kolom_udara]
rain_df['All Particles'] = rain_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].sum(axis=1)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=rain_df, x='All Particles', hue='RAIN', kde=True, bins=30, alpha=0.5)
plt.xlabel('Semua Partikel')
plt.ylabel('Frekuensi')
plt.title('Distribusi Semua Partikel saat Hujan dan Tidak Hujan')
plt.legend(title='Rain', loc='upper right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Pada setiap stasiun rata-rata sangat tidak sehat
# - hujan mempengaruhi

# %%
# !pip freeze > requirements.txt
